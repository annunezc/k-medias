# %% [markdown]
# # Explore here

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/k-means-project-tutorial/main/housing.csv')
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
df2 = df[['MedInc','Latitude','Longitude']]
df2
# Out:
#        MedInc  Latitude  Longitude
# 0      8.3252     37.88    -122.23
# 1      8.3014     37.86    -122.22
# 2      7.2574     37.85    -122.24
# 3      5.6431     37.85    -122.25
# 4      3.8462     37.85    -122.25
# ...       ...       ...        ...
# 20635  1.5603     39.48    -121.09
# 20636  2.5568     39.49    -121.21
# 20637  1.7000     39.43    -121.22
# 20638  1.8672     39.43    -121.32
# 20639  2.3886     39.37    -121.24
#
# [20640 rows x 3 columns]

# %%
df2.info()

#lo unico que se haria del eda es rellenar datos faltantes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MedInc     20640 non-null  float64
#  1   Latitude   20640 non-null  float64
#  2   Longitude  20640 non-null  float64
# dtypes: float64(3)
# memory usage: 483.9 KB

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, _ , _ = train_test_split(df2,_,test_size=0.2,random_state=42)

# no se coloca y predicho porque se realizan clusters, datos historicos vs datos nuevos.

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=6,random_state=42)

X_train['cluster'] = model.fit_predict(X_train)

X_train
# Out:
#        MedInc  Latitude  Longitude  cluster
# 14196  3.2596     32.71    -117.03        3
# 8267   3.8125     33.77    -118.16        1
# 17445  4.1563     34.66    -120.48        1
# 14265  1.9425     32.69    -117.11        3
# 2271   3.5542     36.78    -119.80        5
# ...       ...       ...        ...      ...
# 11284  6.3700     33.78    -117.96        2
# 11964  3.0500     34.02    -117.43        3
# 5390   2.9344     34.03    -118.38        3
# 860    5.7192     37.58    -121.96        0
# 15795  2.5755     37.77    -122.42        5
#
# [16512 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

colors = ['blue', 'red', 'orange', 'green', 'purple', 'gray']

for i, color in zip(X_train['cluster'].unique(), colors):
    subset = X_train[X_train['cluster'] == i]
    ax.scatter(subset['Longitude'], subset['Latitude'], subset['MedInc'],
               s=50, alpha=0.5, marker='o', c=[color], label=f'Cluster {i}')

ax.view_init(elev=80, azim=-120)

ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
ax.set_zlabel('Ingresos Medios')
ax.legend(title='Clusters')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

colors = ['blue', 'red', 'orange', 'green', 'purple', 'gray']

# Graficar los clusters
for i, color in zip(X_train['cluster'].unique(), colors):
    subset = X_train[X_train['cluster'] == i]
    ax.scatter(subset['Longitude'], subset['Latitude'], subset['MedInc'],
               s=50, alpha=0.5, marker='o', c=[color], label=f'Cluster {i}')

# Coordenadas del punto a destacar
MedInc = 4.1563	
Latitude = 34.66	
Longitude = -120.48

# Graficar el punto destacado
ax.scatter(Longitude, Latitude, MedInc,
           s=200, c='black', marker='X', label='Punto destacado')

# Opcional: etiqueta de texto
ax.text(Longitude, Latitude, MedInc + 0.2,
        'Punto especial', color='black', fontsize=10)

# Ajustar vista y etiquetas
ax.view_init(elev=80, azim=-120)
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
ax.set_zlabel('Ingresos Medios')
ax.legend(title='Clusters')
plt.show()

# %%
X_train.sort_values(by='MedInc', ascending=False).head(10)
# Out:
#         MedInc  Latitude  Longitude  cluster
# 17170  15.0001     37.43    -122.27        4
# 5281   15.0001     34.05    -118.49        4
# 8849   15.0001     34.08    -118.40        4
# 4604   15.0001     34.06    -118.33        4
# 8847   15.0001     34.09    -118.40        4
# 6727   15.0001     34.12    -118.12        4
# 4606   15.0001     34.07    -118.33        4
# 5257   15.0001     34.06    -118.49        4
# 17166  15.0001     37.40    -122.22        4
# 17111  15.0001     37.46    -122.18        4

# %%
X_train.sort_values(by='MedInc', ascending=True).head(10)
# Out:
#        MedInc  Latitude  Longitude  cluster
# 3249   0.4999     36.09    -119.99        3
# 6343   0.4999     34.06    -117.75        3
# 20091  0.4999     38.07    -120.19        5
# 13999  0.4999     34.69    -116.90        3
# 3258   0.4999     39.42    -122.89        5
# 19523  0.4999     37.65    -121.01        5
# 5213   0.4999     33.93    -118.28        3
# 4861   0.4999     34.02    -118.28        3
# 73     0.4999     37.81    -122.29        5
# 19800  0.4999     40.43    -123.32        5

# %%
X_test['cluster'] = model.predict(X_test)
X_test
# Out:
#        MedInc  Latitude  Longitude  cluster
# 20046  1.6812     36.06    -119.01        3
# 3024   2.5313     35.14    -119.46        3
# 15663  3.4801     37.80    -122.44        5
# 20484  5.7376     34.28    -118.72        2
# 9814   3.7250     36.62    -121.93        5
# ...       ...       ...        ...      ...
# 15362  4.6050     33.36    -117.22        1
# 16623  2.7266     35.36    -120.83        5
# 18086  9.2298     37.31    -122.05        4
# 2144   2.7850     36.77    -119.76        5
# 3665   3.5521     34.22    -118.37        1
#
# [4128 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111,projection='3d')

colors=['blue','red','orange','green','purple','gray']

for i, color in zip(X_train['cluster'].unique(),colors):
    subset = X_train[X_train['cluster']==i]
    ax.scatter(subset['Longitude'],subset['Latitude'],subset['MedInc'],s=50,alpha=0.5,marker='o',c=[color], label=f'Cluster {i}')

for i, color in zip(X_train['cluster'].unique(),colors):
    subset = X_test[X_test['cluster']==i]
    ax.scatter(subset['Longitude'],subset['Latitude'],subset['MedInc'],s=30,alpha=0.8,marker='x',c=[color], label=f'train {i}')

ax.view_init(elev = 80,azim=-120)

ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
ax.set_zlabel('Ingresos Medios')
ax.legend(title='Clusters')

plt.show()

# %%
y_train = X_train['cluster']
y_test = X_test['cluster']
X_train = X_train.drop('cluster',axis=1)
X_test = X_test.drop('cluster',axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

model_rf = RandomForestClassifier(random_state=42)
model_xgb = XGBClassifier(random_state=42)

model_rf.fit(X_train,y_train)
model_xgb.fit(X_train,y_train)

y_pred_rf = model_rf.predict(X_test)
y_pred_xgb = model_xgb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print(f'La precisión del RF es {accuracy_score(y_test,y_pred_rf)}')
print(f'La precisión del XGB es {accuracy_score(y_test,y_pred_xgb)}')
# Out:
# La precisión del RF es 0.9963662790697675
# La precisión del XGB es 0.9941860465116279

# %%
from pickle import dump

dump(model,open('../models/k_means_6_42.sav','wb'))
dump(model_rf,open('../models/random_forest_default_42.sav','wb'))
model_xgb.save_model('../models/xgboost_default_42.json')
